# %%
import cv2
import matplotlib.pyplot as plt
#print(cv2.__version__)
# Out:
# 4.1.1

# %%
# Read image 
img = cv2.imread('38.png', cv2.IMREAD_COLOR) 
# Convert the image to gray-scale
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
# Find the edges in the image using canny detector
edges = cv2.Canny(gray, 50, 150,apertureSize = 3)
fig, (ax1, ax2) = plt.subplots(1,2)
    #plt.imshow(edges,cmap = 'gray')
ax1.imshow(img)
ax2.imshow(edges,cmap = 'gray')

# %%
# Detect points that form a line
minLineLength = 250
maxLineGap = 2
lines = cv2.HoughLinesP(edges,1,np.pi/90,50,minLineLength,maxLineGap)
    # Draw lines on the imag5
for line in lines:
    x1, y1, x2, y2 = line[0]
    cv2.line(img,(x1,y1),(x2,y2),(255,0,0),2)
    

    #cv2.imshow("Result Image", img)
    #cv2.imwrite('line_detected.png',img)
plt.figure(figsize = (10,20))
plt.imshow(img,cmap = 'gray')

# %%
# Read image 
img = cv2.imread('16908.png', cv2.IMREAD_COLOR) 
# Convert the image to gray-scale
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
# Find the edges in the image using canny detector
edges = cv2.Canny(gray, 20, 100,apertureSize = 3)
fig, (ax1, ax2) = plt.subplots(1,2)
    #plt.imshow(edges,cmap = 'gray')
ax1.imshow(img)
ax2.imshow(edges,cmap = 'gray')

# %%
# Detect points that form a line
minLineLength = 250
maxLineGap = 10
lines = cv2.HoughLinesP(edges,1,np.pi/90,50,minLineLength,maxLineGap)
    # Draw lines on the imag5
for line in lines:
    x1, y1, x2, y2 = line[0]
    cv2.line(img,(x1,y1),(x2,y2),(255,0,0),2)
    

    #cv2.imshow("Result Image", img)
    #cv2.imwrite('line_detected.png',img)
plt.figure(figsize = (10,20))
plt.imshow(img,cmap = 'gray')
